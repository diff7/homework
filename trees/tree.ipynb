# %%
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt

from tree import Stump, DecisionTree

# %%
data = datasets.load_wine()
features = data['data']
targets = data['target']
target_names = data['target_names']
feature_names = data['feature_names']

# %% [markdown]
# ### Решающий пень

# %%
stump = Stump(len(set(targets)))
res = stump.get_split(features, targets)
print(f'threshold : {res[0]}, feature {res[1]}')
# Out:
# threshold : 1.5750000000000002, feature 6

# %% [markdown]
# ### Сравним с sklearn

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
clf = DecisionTreeClassifier(max_depth=1, criterion='entropy')
clf.fit(features, targets)
fig = plt.figure(figsize=(6,6))
tree.plot_tree(clf);

# %% [markdown]
# ### Решающее дерево

# %%
dt = DecisionTree(maxdepth=6)

# %%
dt.fit(features[50:], targets[50:])

# %%
n = 50
predict = dt.predict(iris_features[:n])
accuracy = sum(iris_target[:n] == np.array(predict))/n
print(f'accuracy: {accuracy}')
# Out:
# accuracy: 0.8

# %% [markdown]
# ### Сравним с sklearn

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
clf = DecisionTreeClassifier(max_depth=6, criterion='entropy')

# %%
n = 50
clf.fit(features[n:], targets[n:])
predict = clf.predict(iris_features[:n])
accuracy = sum(iris_target[:n] == np.array(predict))/n
print(f'accuracy: {accuracy}')
# Out:
# accuracy: 0.8
